# %%
# Author: Xiang Zhang (zhan6668)
# Description: This IPython notebook pre-process the movie data for Avatar-Project1-Phase3

import os, sys, re
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

# %%
# Design a function to rename the titles
def renameTitle(x):
    title = x
    year = ''
    if "(" in x:
        #print(x.split(" ("))
        title = x.rsplit(" (",1)[0]
        year = x.rsplit(" (",1)[-1][:-1]
    return [title, year]

# Design a function to rename the genres
def renameGenres(x):
    genre_list = [x]
    if "|" in x:
        genre_list = x.split("|")
    return genre_list

# %%
# 1. links.csv
df_link = pd.read_csv('./GroupLens-MovieLens-25m/links.csv', index_col=0)

# %%
df_link
# Out:
#           imdbId    tmdbId
# movieId
# 1         114709     862.0
# 2         113497    8844.0
# 3         113228   15602.0
# 4         114885   31357.0
# 5         113041   11862.0
# ...          ...       ...
# 209157   6671244  499546.0
# 209159    297986   63407.0
# 209163   6755366  553036.0
# 209169    249603  162892.0
# 209171     55323   79513.0
#
# [62423 rows x 2 columns]

# %%
# 2. movies.csv
df_movie = pd.read_csv('./GroupLens-MovieLens-25m/movies.csv', index_col=0)

# %%
mv_title_list = []
mv_year_list = []
for mv in df_movie['title'].tolist():
    mv = mv.replace(u'\xa0', u' ')
    [title, year] = renameTitle(mv)
    mv_title_list.append(title)
    mv_year_list.append(year)

# %%
df_movie['movie_title'] = mv_title_list
df_movie['movie_year'] = mv_year_list

# %%
mv_genre_list = []
for mv in df_movie['genres'].tolist():
    genre_list = renameGenres(mv)
    mv_genre_list.append(genre_list)

# %%
df_movie['movie_genres'] = mv_genre_list

# %%
df_movie
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
# ...                                     ...
# 209157                            We (2018)
# 209159            Window of the Soul (2001)
# 209163                     Bad Poems (2018)
# 209169                  A Girl Thing (2001)
# 209171       Women of Devil's Island (1962)
#
#                                               genres  \
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# 209157                                         Drama
# 209159                                   Documentary
# 209163                                  Comedy|Drama
# 209169                            (no genres listed)
# 209171                        Action|Adventure|Drama
#
#                          movie_title movie_year  \
# movieId
# 1                          Toy Story       1995
# 2                            Jumanji       1995
# 3                   Grumpier Old Men       1995
# 4                  Waiting to Exhale       1995
# 5        Father of the Bride Part II       1995
# ...                              ...        ...
# 209157                            We       2018
# 209159            Window of the Soul       2001
# 209163                     Bad Poems       2018
# 209169                  A Girl Thing       2001
# 209171       Women of Devil's Island       1962
#
#                                               movie_genres
# movieId
# 1        [Adventure, Animation, Children, Comedy, Fantasy]
# 2                           [Adventure, Children, Fantasy]
# 3                                        [Comedy, Romance]
# 4                                 [Comedy, Drama, Romance]
# 5                                                 [Comedy]
# ...                                                    ...
# 209157                                             [Drama]
# 209159                                       [Documentary]
# 209163                                     [Comedy, Drama]
# 209169                                [(no genres listed)]
# 209171                          [Action, Adventure, Drama]
#
# [62423 rows x 5 columns]

# %%
df_movie
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
# ...                                     ...
# 209157                            We (2018)
# 209159            Window of the Soul (2001)
# 209163                     Bad Poems (2018)
# 209169                  A Girl Thing (2001)
# 209171       Women of Devil's Island (1962)
#
#                                               genres  \
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# 209157                                         Drama
# 209159                                   Documentary
# 209163                                  Comedy|Drama
# 209169                            (no genres listed)
# 209171                        Action|Adventure|Drama
#
#                          movie_title movie_year
# movieId
# 1                          Toy Story       1995
# 2                            Jumanji       1995
# 3                   Grumpier Old Men       1995
# 4                  Waiting to Exhale       1995
# 5        Father of the Bride Part II       1995
# ...                              ...        ...
# 209157                            We       2018
# 209159            Window of the Soul       2001
# 209163                     Bad Poems       2018
# 209169                  A Girl Thing       2001
# 209171       Women of Devil's Island       1962
#
# [62423 rows x 4 columns]

# %%
df_movie_new = df_movie.join(df_link, on='movieId')[['imdbId','movie_title', 'movie_year', 'movie_genres']]

# %%
def renameIMDbId(x):
    x_len = len(str(x))
    if x_len == 7:
        x = 'tt' + str(x)
    elif x_len<7:
        x = 'tt' + (7-x_len)*'0' + str(x)
    else:
        x = 'tt' + str(x)
        #print('larger than 7')
        #print(x)
    return x

# %%
df_movie_new['imdbId'].apply(renameIMDbId)
# Out:
# movieId
# 1         tt0114709
# 2         tt0113497
# 3         tt0113228
# 4         tt0114885
# 5         tt0113041
#             ...
# 209157    tt6671244
# 209159    tt0297986
# 209163    tt6755366
# 209169    tt0249603
# 209171    tt0055323
# Name: imdbId, Length: 62423, dtype: object

# %%
df_movie_new['imdbId'] = df_movie_new['imdbId'].apply(renameIMDbId)

# %%
# 3. read in IMDb ratings
df_imdb_rating = pd.read_csv('./IMDb/title.ratings.tsv', sep='\t', index_col=0)

# %%
df_movie_new = df_movie_new.join(df_imdb_rating['averageRating'], on='imdbId')

# %%
df_movie_new.set_index('imdbId').to_csv('movies_info.csv')

# %%
df_movie_new
# Out:
#             imdbId                  movie_title movie_year  \
# movieId
# 1        tt0114709                    Toy Story       1995
# 2        tt0113497                      Jumanji       1995
# 3        tt0113228             Grumpier Old Men       1995
# 4        tt0114885            Waiting to Exhale       1995
# 5        tt0113041  Father of the Bride Part II       1995
# ...            ...                          ...        ...
# 209157   tt6671244                           We       2018
# 209159   tt0297986           Window of the Soul       2001
# 209163   tt6755366                    Bad Poems       2018
# 209169   tt0249603                 A Girl Thing       2001
# 209171   tt0055323      Women of Devil's Island       1962
#
#                                               movie_genres  averageRating
# movieId
# 1        [Adventure, Animation, Children, Comedy, Fantasy]            8.3
# 2                           [Adventure, Children, Fantasy]            7.0
# 3                                        [Comedy, Romance]            6.7
# 4                                 [Comedy, Drama, Romance]            6.0
# 5                                                 [Comedy]            6.1
# ...                                                    ...            ...
# 209157                                             [Drama]            5.7
# 209159                                       [Documentary]            7.9
# 209163                                     [Comedy, Drama]            7.7
# 209169                                [(no genres listed)]            6.2
# 209171                          [Action, Adventure, Drama]            4.3
#
# [62423 rows x 5 columns]

# %%
# 4. now we turn to human - actor/actress/director
df_name = pd.read_csv('./IMDb/name.basics.tsv',sep='\t',index_col=0)

# %%
df_name
# Out:
#                   primaryName birthYear deathYear  \
# nconst
# nm0000001        Fred Astaire      1899      1987
# nm0000002       Lauren Bacall      1924      2014
# nm0000003     Brigitte Bardot      1934        \N
# nm0000004        John Belushi      1949      1982
# nm0000005      Ingmar Bergman      1918      2007
# ...                       ...       ...       ...
# nm9993714   Romeo del Rosario        \N        \N
# nm9993716       Essias Loberg        \N        \N
# nm9993717  Harikrishnan Rajan        \N        \N
# nm9993718         Aayush Nair        \N        \N
# nm9993719          Andre Hill        \N        \N
#
#                              primaryProfession  \
# nconst
# nm0000001       soundtrack,actor,miscellaneous
# nm0000002                   actress,soundtrack
# nm0000003  actress,soundtrack,music_department
# nm0000004              actor,soundtrack,writer
# nm0000005                writer,director,actor
# ...                                        ...
# nm9993714  animation_department,art_department
# nm9993716                                  NaN
# nm9993717                      cinematographer
# nm9993718                      cinematographer
# nm9993719                                  NaN
#
#                                     knownForTitles
# nconst
# nm0000001  tt0050419,tt0031983,tt0072308,tt0053137
# nm0000002  tt0037382,tt0117057,tt0038355,tt0071877
# nm0000003  tt0059956,tt0057345,tt0054452,tt0049189
# nm0000004  tt0078723,tt0072562,tt0080455,tt0077975
# nm0000005  tt0083922,tt0060827,tt0050976,tt0050986
# ...                                            ...
# nm9993714                                tt2455546
# nm9993716                                       \N
# nm9993717                                tt8736744
# nm9993718                                       \N
# nm9993719                                       \N
#
# [10701883 rows x 5 columns]

# %%
print(df_name.shape[0])
print(df_name[df_name['primaryProfession'].isnull()].shape[0])
# Out:
# 10701883
# 2246089

# %%
# identify whether this person is an actor/actress/director
label_list = []
counter = 0
for row in df_name.iterrows():
    #idx = row[0]
    local_label_list = []
    if pd.isnull(row[1]['primaryProfession']):
        local_label_list.append('')
    else:
        if 'actor' in row[1]['primaryProfession']:
            local_label_list.append('actor')
        if 'actress' in row[1]['primaryProfession']:
            local_label_list.append('actress')
        if 'director' in row[1]['primaryProfession']:
            local_label_list.append('director')
        if len(local_label_list) > 1:
            #print(local_label_list)
            counter += 1
        
    label_list.append(local_label_list)

# %%
counter
# Out:
# 167821

# %%
df_name['professionLabel'] = label_list

# %%
# Out:
#                   primaryName birthYear deathYear  \
# nconst
# nm0000001        Fred Astaire      1899      1987
# nm0000002       Lauren Bacall      1924      2014
# nm0000003     Brigitte Bardot      1934        \N
# nm0000004        John Belushi      1949      1982
# nm0000005      Ingmar Bergman      1918      2007
# ...                       ...       ...       ...
# nm9993714   Romeo del Rosario        \N        \N
# nm9993716       Essias Loberg        \N        \N
# nm9993717  Harikrishnan Rajan        \N        \N
# nm9993718         Aayush Nair        \N        \N
# nm9993719          Andre Hill        \N        \N
#
#                              primaryProfession  \
# nconst
# nm0000001       soundtrack,actor,miscellaneous
# nm0000002                   actress,soundtrack
# nm0000003  actress,soundtrack,music_department
# nm0000004              actor,soundtrack,writer
# nm0000005                writer,director,actor
# ...                                        ...
# nm9993714  animation_department,art_department
# nm9993716                                  NaN
# nm9993717                      cinematographer
# nm9993718                      cinematographer
# nm9993719                                  NaN
#
#                                     knownForTitles    professionLabel
# nconst
# nm0000001  tt0050419,tt0031983,tt0072308,tt0053137            [actor]
# nm0000002  tt0037382,tt0117057,tt0038355,tt0071877          [actress]
# nm0000003  tt0059956,tt0057345,tt0054452,tt0049189          [actress]
# nm0000004  tt0078723,tt0072562,tt0080455,tt0077975            [actor]
# nm0000005  tt0083922,tt0060827,tt0050976,tt0050986  [actor, director]
# ...                                            ...                ...
# nm9993714                                tt2455546                 []
# nm9993716                                       \N                 []
# nm9993717                                tt8736744                 []
# nm9993718                                       \N                 []
# nm9993719                                       \N                 []
#
# [10701883 rows x 6 columns]

# %%
df_name_simp = df_name[['primaryName', 'knownForTitles','professionLabel']]

# %%
df_name_simp_1work = df_name_simp[df_name_simp['professionLabel'].str.len()==1]

# %%
df_name_simp_1work = df_name_simp_1work[df_name_simp_1work['knownForTitles'].str.len()>2]

# %%
link_list = []
for row in df_name_simp_1work.iterrows():
    profess = row[1]['professionLabel'][0]
    if profess == 'actor' or profess == 'actress':
        link_list.append('acted_in')
    elif profess == 'director':
        link_list.append('directed')
    else:
        link_list.append('null')

# %%
len(link_list)
# Out:
# 5096620

# %%
df_name_simp_1work['link'] = link_list
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_name_simp_1work = df_name_simp_1work[df_name_simp_1work['link']!='null']

# %%
df_name_simp_1work.to_csv('./input_Neo4j/workers_1label.csv')

# %%
df_name_simp_1work[df_name_simp_1work['link']=='acted_in'].to_csv('./input_Neo4j/workers_1label_act.csv')

# %%
df_name_simp_1work[df_name_simp_1work['link']=='directed'].to_csv('./input_Neo4j/workers_1label_direct.csv')

# %%
# now look at multi-label
df_name_simp[df_name_simp['professionLabel'].str.len()>2]
# Out:
#                primaryName       knownForTitles             professionLabel
# nconst
# nm5510978  Brigitte Toubia  tt2692346,tt4933766  [actor, actress, director]
# nm7434057      Lisa Conlin  tt7061882,tt4832800  [actor, actress, director]

# %%
# manually revise after checking
df_name_simp.loc['nm5510978']['professionLabel'] = ['actress', 'director']
df_name_simp.loc['nm7434057']['professionLabel'] = ['actress', 'director']

# %%
df_name_simp[df_name_simp['professionLabel'].str.len()>2]
# Out:
# Empty DataFrame
# Columns: [primaryName, knownForTitles, professionLabel]
# Index: []

# %%
df_name_simp[df_name_simp['professionLabel'].str.len()==2]
# Out:
#                  primaryName                           knownForTitles  \
# nconst
# nm0000005     Ingmar Bergman  tt0083922,tt0060827,tt0050976,tt0050986
# nm0000008      Marlon Brando  tt0047296,tt0070849,tt0078788,tt0068646
# nm0000010       James Cagney  tt0035575,tt0042041,tt0029870,tt0031867
# nm0000024       John Gielgud  tt0071877,tt0082031,tt0117631,tt0045943
# nm0000032    Charlton Heston  tt0070723,tt0063442,tt0052618,tt0049833
# ...                      ...                                      ...
# nm9993023         Tajda Meze                                tt7708648
# nm9993125  Alejandro Bordier            tt8742880,tt9121640,tt8866550
# nm9993142        Rebekah Lee          tt11343630,tt10962838,tt8141238
# nm9993379    Fanny Hozleiter                                tt8743182
# nm9993380     Pegasus Envoyé                                tt8743182
#
#                professionLabel
# nconst
# nm0000005    [actor, director]
# nm0000008    [actor, director]
# nm0000010    [actor, director]
# nm0000024    [actor, director]
# nm0000032    [actor, director]
# ...                        ...
# nm9993023  [actress, director]
# nm9993125    [actor, director]
# nm9993142  [actress, director]
# nm9993379  [actress, director]
# nm9993380    [actor, director]
#
# [167821 rows x 3 columns]

# %%
df_name_simp[df_name_simp['professionLabel'].str.len()==2].to_csv('./input_Neo4j/workers_2labels.csv')

# %%
df_name_simp_2work = df_name_simp[df_name_simp['professionLabel'].str.len()==2]

# %%
df_movie_new
# Out:
#             imdbId                  movie_title movie_year  \
# movieId
# 1        tt0114709                    Toy Story       1995
# 2        tt0113497                      Jumanji       1995
# 3        tt0113228             Grumpier Old Men       1995
# 4        tt0114885            Waiting to Exhale       1995
# 5        tt0113041  Father of the Bride Part II       1995
# ...            ...                          ...        ...
# 209157   tt6671244                           We       2018
# 209159   tt0297986           Window of the Soul       2001
# 209163   tt6755366                    Bad Poems       2018
# 209169   tt0249603                 A Girl Thing       2001
# 209171   tt0055323      Women of Devil's Island       1962
#
#                                               movie_genres  averageRating
# movieId
# 1        [Adventure, Animation, Children, Comedy, Fantasy]            8.3
# 2                           [Adventure, Children, Fantasy]            7.0
# 3                                        [Comedy, Romance]            6.7
# 4                                 [Comedy, Drama, Romance]            6.0
# 5                                                 [Comedy]            6.1
# ...                                                    ...            ...
# 209157                                             [Drama]            5.7
# 209159                                       [Documentary]            7.9
# 209163                                     [Comedy, Drama]            7.7
# 209169                                [(no genres listed)]            6.2
# 209171                          [Action, Adventure, Drama]            4.3
#
# [62423 rows x 5 columns]

# %%
df_crew = pd.read_csv('./IMDb/title.crew.tsv', sep='\t',index_col=0)

# %%
df_crew
# Out:
#                      directors                        writers
# tconst
# tt0000001            nm0005690                             \N
# tt0000002            nm0721526                             \N
# tt0000003            nm0721526                             \N
# tt0000004            nm0721526                             \N
# tt0000005            nm0005690                             \N
# ...                        ...                            ...
# tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# tt9916850  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# tt9916852  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# tt9916856           nm10538645                      nm6951431
# tt9916880            nm0996406            nm1482639,nm2586970
#
# [7594498 rows x 2 columns]

# %%
df_movie_new.join(df_crew['directors'], on='imdbId').set_index('imdbId').to_csv('./input_Neo4j/movies_info.csv')

# %%
df_movie_new = df_movie_new.join(df_crew['directors'], on='imdbId')

# %%
df_movie_new
# Out:
#             imdbId                  movie_title movie_year  \
# movieId
# 1        tt0114709                    Toy Story       1995
# 2        tt0113497                      Jumanji       1995
# 3        tt0113228             Grumpier Old Men       1995
# 4        tt0114885            Waiting to Exhale       1995
# 5        tt0113041  Father of the Bride Part II       1995
# ...            ...                          ...        ...
# 209157   tt6671244                           We       2018
# 209159   tt0297986           Window of the Soul       2001
# 209163   tt6755366                    Bad Poems       2018
# 209169   tt0249603                 A Girl Thing       2001
# 209171   tt0055323      Women of Devil's Island       1962
#
#                                               movie_genres  averageRating  \
# movieId
# 1        [Adventure, Animation, Children, Comedy, Fantasy]            8.3
# 2                           [Adventure, Children, Fantasy]            7.0
# 3                                        [Comedy, Romance]            6.7
# 4                                 [Comedy, Drama, Romance]            6.0
# 5                                                 [Comedy]            6.1
# ...                                                    ...            ...
# 209157                                             [Drama]            5.7
# 209159                                       [Documentary]            7.9
# 209163                                     [Comedy, Drama]            7.7
# 209169                                [(no genres listed)]            6.2
# 209171                          [Action, Adventure, Drama]            4.3
#
#                    directors
# movieId
# 1                  nm0005124
# 2                  nm0002653
# 3                  nm0222043
# 4                  nm0001845
# 5                  nm0796124
# ...                      ...
# 209157             nm1415482
# 209159   nm1065588,nm0142504
# 209163             nm2520391
# 209169             nm0003022
# 209171             nm0659992
#
# [62423 rows x 6 columns]

# %%
# 0320 change the format of movie_genres
df_movie_new = pd.read_csv('./input_Neo4j/movies_info.csv',index_col=0)

# %%
def reformat_genres(x):
    return ",".join(eval(x))

# %%
df_movie_new['movie_genres'] = df_movie_new['movie_genres'].apply(reformat_genres)

# %%
df_movie_new
# Out:
#                            movie_title movie_year  \
# imdbId
# tt0114709                    Toy Story       1995
# tt0113497                      Jumanji       1995
# tt0113228             Grumpier Old Men       1995
# tt0114885            Waiting to Exhale       1995
# tt0113041  Father of the Bride Part II       1995
# ...                                ...        ...
# tt6671244                           We       2018
# tt0297986           Window of the Soul       2001
# tt6755366                    Bad Poems       2018
# tt0249603                 A Girl Thing       2001
# tt0055323      Women of Devil's Island       1962
#
#                                           movie_genres  averageRating  \
# imdbId
# tt0114709  Adventure,Animation,Children,Comedy,Fantasy            8.3
# tt0113497                   Adventure,Children,Fantasy            7.0
# tt0113228                               Comedy,Romance            6.7
# tt0114885                         Comedy,Drama,Romance            6.0
# tt0113041                                       Comedy            6.1
# ...                                                ...            ...
# tt6671244                                        Drama            5.7
# tt0297986                                  Documentary            7.9
# tt6755366                                 Comedy,Drama            7.7
# tt0249603                           (no genres listed)            6.2
# tt0055323                       Action,Adventure,Drama            4.3
#
#                      directors
# imdbId
# tt0114709            nm0005124
# tt0113497            nm0002653
# tt0113228            nm0222043
# tt0114885            nm0001845
# tt0113041            nm0796124
# ...                        ...
# tt6671244            nm1415482
# tt0297986  nm1065588,nm0142504
# tt6755366            nm2520391
# tt0249603            nm0003022
# tt0055323            nm0659992
#
# [62423 rows x 5 columns]

# %%
df_movie_new.to_csv('./input_Neo4j/movies_info_0321.csv')

# %%
df_name_simp_2work
# Out:
#                  primaryName                           knownForTitles  \
# nconst
# nm0000005     Ingmar Bergman  tt0083922,tt0060827,tt0050976,tt0050986
# nm0000008      Marlon Brando  tt0047296,tt0070849,tt0078788,tt0068646
# nm0000010       James Cagney  tt0035575,tt0042041,tt0029870,tt0031867
# nm0000024       John Gielgud  tt0071877,tt0082031,tt0117631,tt0045943
# nm0000032    Charlton Heston  tt0070723,tt0063442,tt0052618,tt0049833
# ...                      ...                                      ...
# nm9993023         Tajda Meze                                tt7708648
# nm9993125  Alejandro Bordier            tt8742880,tt9121640,tt8866550
# nm9993142        Rebekah Lee          tt11343630,tt10962838,tt8141238
# nm9993379    Fanny Hozleiter                                tt8743182
# nm9993380     Pegasus Envoyé                                tt8743182
#
#                professionLabel
# nconst
# nm0000005    [actor, director]
# nm0000008    [actor, director]
# nm0000010    [actor, director]
# nm0000024    [actor, director]
# nm0000032    [actor, director]
# ...                        ...
# nm9993023  [actress, director]
# nm9993125    [actor, director]
# nm9993142  [actress, director]
# nm9993379  [actress, director]
# nm9993380    [actor, director]
#
# [167821 rows x 3 columns]

# %%
# 5. customer rating
df_cratings = pd.read_csv('./GroupLens-MovieLens-25m/ratings.csv')

# %%
df_cratings.shape
# Out:
# (25000095, 4)

# %%
df_cratings = df_cratings.join(df_movie_new, on='movieId')[['userId','imdbId','rating']]

# %%
df_cratings
# Out:
#           userId     imdbId  rating
# 0              1  tt0110912     5.0
# 1              1  tt0111495     3.5
# 2              1  tt0108394     5.0
# 3              1  tt0114787     5.0
# 4              1  tt0045152     3.5
# ...          ...        ...     ...
# 25000090  162541  tt0382932     4.5
# 25000091  162541  tt0389790     2.5
# 25000092  162541  tt0952640     2.0
# 25000093  162541  tt0468569     4.0
# 25000094  162541  tt1013753     5.0
#
# [25000095 rows x 3 columns]

# %%
def renameCustId(x):
    x_len = len(str(x))
    if x_len == 6:
        x = 'c' + str(x)
    elif x_len<6:
        x = 'c' + (6-x_len)*'0' + str(x)
    else:
        x = 'c' + str(x)
        #print('larger than 6')
        #print(x)
    return x

# %%
df_cratings['userId'] = df_cratings['userId'].apply(renameCustId)

# %%
df_cratings.set_index('userId').to_csv('./input_Neo4j/customer_ratings.csv')

# %%
df_cratings.set_index('userId')
# Out:
#             imdbId  rating
# userId
# c000001  tt0110912     5.0
# c000001  tt0111495     3.5
# c000001  tt0108394     5.0
# c000001  tt0114787     5.0
# c000001  tt0045152     3.5
# ...            ...     ...
# c162541  tt0382932     4.5
# c162541  tt0389790     2.5
# c162541  tt0952640     2.0
# c162541  tt0468569     4.0
# c162541  tt1013753     5.0
#
# [25000095 rows x 2 columns]

# %%
df_movie_new.set_index('imdbId')
# Out:
#                            movie_title movie_year  \
# imdbId
# tt0114709                    Toy Story       1995
# tt0113497                      Jumanji       1995
# tt0113228             Grumpier Old Men       1995
# tt0114885            Waiting to Exhale       1995
# tt0113041  Father of the Bride Part II       1995
# ...                                ...        ...
# tt6671244                           We       2018
# tt0297986           Window of the Soul       2001
# tt6755366                    Bad Poems       2018
# tt0249603                 A Girl Thing       2001
# tt0055323      Women of Devil's Island       1962
#
#                                                 movie_genres  averageRating  \
# imdbId
# tt0114709  [Adventure, Animation, Children, Comedy, Fantasy]            8.3
# tt0113497                     [Adventure, Children, Fantasy]            7.0
# tt0113228                                  [Comedy, Romance]            6.7
# tt0114885                           [Comedy, Drama, Romance]            6.0
# tt0113041                                           [Comedy]            6.1
# ...                                                      ...            ...
# tt6671244                                            [Drama]            5.7
# tt0297986                                      [Documentary]            7.9
# tt6755366                                    [Comedy, Drama]            7.7
# tt0249603                               [(no genres listed)]            6.2
# tt0055323                         [Action, Adventure, Drama]            4.3
#
#                      directors
# imdbId
# tt0114709            nm0005124
# tt0113497            nm0002653
# tt0113228            nm0222043
# tt0114885            nm0001845
# tt0113041            nm0796124
# ...                        ...
# tt6671244            nm1415482
# tt0297986  nm1065588,nm0142504
# tt6755366            nm2520391
# tt0249603            nm0003022
# tt0055323            nm0659992
#
# [62423 rows x 5 columns]

# %%
df_df_name_simp_1work_performer = df_name_simp_1work[df_name_simp_1work['link']=='acted_in']

# %%
df_df_name_simp_1work_performer.shape[0]
# Out:
# 3487727

# %%
df_df_name_simp_1work_performer['professionLabel_2'] = ['performer']*3487727
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_df_name_simp_1work_performer.to_csv('./input_Neo4j/workers_1label_act.csv')

# %%
df_df_name_simp_1work_performer
# Out:
#                 primaryName                             knownForTitles  \
# nconst
# nm0000001      Fred Astaire    tt0050419,tt0031983,tt0072308,tt0053137
# nm0000002     Lauren Bacall    tt0037382,tt0117057,tt0038355,tt0071877
# nm0000003   Brigitte Bardot    tt0059956,tt0057345,tt0054452,tt0049189
# nm0000004      John Belushi    tt0078723,tt0072562,tt0080455,tt0077975
# nm0000006    Ingrid Bergman    tt0034583,tt0038787,tt0038109,tt0077711
# ...                     ...                                        ...
# nm9993694    Chinmay Mishra   tt9083282,tt10140990,tt8737752,tt9097592
# nm9993698         Sebi John                                  tt8736744
# nm9993699        Dani Jacob                                  tt8736744
# nm9993701  Sanjai Kuriakose                                  tt8736744
# nm9993703   James Craigmyle  tt6914160,tt6225166,tt10627062,tt11212278
#
#           professionLabel      link professionLabel_2
# nconst
# nm0000001         [actor]  acted_in         performer
# nm0000002       [actress]  acted_in         performer
# nm0000003       [actress]  acted_in         performer
# nm0000004         [actor]  acted_in         performer
# nm0000006       [actress]  acted_in         performer
# ...                   ...       ...               ...
# nm9993694         [actor]  acted_in         performer
# nm9993698         [actor]  acted_in         performer
# nm9993699         [actor]  acted_in         performer
# nm9993701         [actor]  acted_in         performer
# nm9993703         [actor]  acted_in         performer
#
# [3487727 rows x 5 columns]

# %%
df_name_simp_1work_director = df_name_simp_1work[df_name_simp_1work['link']=='directed']

# %%
df_name_simp_1work_director.shape
# Out:
# (632346, 4)

# %%
df_name_simp_1work_director['professionLabel_2'] = ['director']*632346
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_name_simp_1work_director.to_csv('./input_Neo4j/workers_1label_direct.csv')

# %%
df_name_simp_1work_director
# Out:
#                   primaryName                               knownForTitles  \
# nconst
# nm0000019    Federico Fellini      tt0056801,tt0047528,tt0053779,tt0050783
# nm0000040     Stanley Kubrick      tt0072684,tt0120663,tt0062622,tt0066921
# nm0000041      Akira Kurosawa      tt0080979,tt0089881,tt0051808,tt0047478
# nm0000076   François Truffaut      tt0075860,tt0070460,tt0053198,tt0055032
# nm0000083         Alan Miller      tt0424773,tt5969604,tt0320978,tt0969216
# ...                       ...                                          ...
# nm9993456     Fernando Balmas                                    tt0131531
# nm9993573  Lakisha Louissaint                                   tt10299418
# nm9993679           Art Jones                                    tt8744074
# nm9993708          Eli Bevins  tt11772858,tt11772904,tt11702702,tt11772940
# nm9993709           Lu Bevins  tt11772904,tt11772858,tt11772940,tt11702702
#
#           professionLabel      link professionLabel_2
# nconst
# nm0000019      [director]  directed          director
# nm0000040      [director]  directed          director
# nm0000041      [director]  directed          director
# nm0000076      [director]  directed          director
# nm0000083      [director]  directed          director
# ...                   ...       ...               ...
# nm9993456      [director]  directed          director
# nm9993573      [director]  directed          director
# nm9993679      [director]  directed          director
# nm9993708      [director]  directed          director
# nm9993709      [director]  directed          director
#
# [632346 rows x 5 columns]

# %%
df_name_simp_2work
# Out:
#                  primaryName                           knownForTitles  \
# nconst
# nm0000005     Ingmar Bergman  tt0083922,tt0060827,tt0050976,tt0050986
# nm0000008      Marlon Brando  tt0047296,tt0070849,tt0078788,tt0068646
# nm0000010       James Cagney  tt0035575,tt0042041,tt0029870,tt0031867
# nm0000024       John Gielgud  tt0071877,tt0082031,tt0117631,tt0045943
# nm0000032    Charlton Heston  tt0070723,tt0063442,tt0052618,tt0049833
# ...                      ...                                      ...
# nm9993023         Tajda Meze                                tt7708648
# nm9993125  Alejandro Bordier            tt8742880,tt9121640,tt8866550
# nm9993142        Rebekah Lee          tt11343630,tt10962838,tt8141238
# nm9993379    Fanny Hozleiter                                tt8743182
# nm9993380     Pegasus Envoyé                                tt8743182
#
#                professionLabel
# nconst
# nm0000005    [actor, director]
# nm0000008    [actor, director]
# nm0000010    [actor, director]
# nm0000024    [actor, director]
# nm0000032    [actor, director]
# ...                        ...
# nm9993023  [actress, director]
# nm9993125    [actor, director]
# nm9993142  [actress, director]
# nm9993379  [actress, director]
# nm9993380    [actor, director]
#
# [167821 rows x 3 columns]

# %%
# 0322: get the subset of customer ratings
df_movie_new = pd.read_csv('./input_Neo4j/movies_info_0321.csv',index_col=0)

# %%
df_movie_new
# Out:
#                            movie_title movie_year  \
# imdbId
# tt0114709                    Toy Story       1995
# tt0113497                      Jumanji       1995
# tt0113228             Grumpier Old Men       1995
# tt0114885            Waiting to Exhale       1995
# tt0113041  Father of the Bride Part II       1995
# ...                                ...        ...
# tt6671244                           We       2018
# tt0297986           Window of the Soul       2001
# tt6755366                    Bad Poems       2018
# tt0249603                 A Girl Thing       2001
# tt0055323      Women of Devil's Island       1962
#
#                                           movie_genres  averageRating  \
# imdbId
# tt0114709  Adventure,Animation,Children,Comedy,Fantasy            8.3
# tt0113497                   Adventure,Children,Fantasy            7.0
# tt0113228                               Comedy,Romance            6.7
# tt0114885                         Comedy,Drama,Romance            6.0
# tt0113041                                       Comedy            6.1
# ...                                                ...            ...
# tt6671244                                        Drama            5.7
# tt0297986                                  Documentary            7.9
# tt6755366                                 Comedy,Drama            7.7
# tt0249603                           (no genres listed)            6.2
# tt0055323                       Action,Adventure,Drama            4.3
#
#                      directors
# imdbId
# tt0114709            nm0005124
# tt0113497            nm0002653
# tt0113228            nm0222043
# tt0114885            nm0001845
# tt0113041            nm0796124
# ...                        ...
# tt6671244            nm1415482
# tt0297986  nm1065588,nm0142504
# tt6755366            nm2520391
# tt0249603            nm0003022
# tt0055323            nm0659992
#
# [62423 rows x 5 columns]

# %%
df_movie_new[df_movie_new['averageRating'].isnull()]
# Out:
#                                                 movie_title movie_year  \
# imdbId
# tt0118114   Wallace & Gromit: The Best of Aardman Animation       1996
# tt0125877                                          Low Life       1994
# tt0038426                                       Costa Brava       1946
# tt0115548                                              Anna       1996
# tt0087690                                       Master, The       1984
# ...                                                     ...        ...
# tt7725112                                  L'Isola di Medea       2016
# tt6552104                     The Fellowship of the Farmers        NaN
# tt7342916                                            Solace       2017
# tt7575076                        China, o Império do Centro       1987
# tt10987544                               The Forest of Love       2019
#
#                              movie_genres  averageRating  directors
# imdbId
# tt0118114      Adventure,Animation,Comedy            NaN        NaN
# tt0125877                           Drama            NaN  nm0478286
# tt0038426                           Drama            NaN  nm0281541
# tt0115548                           Drama            NaN  nm0887814
# tt0087690                          Action            NaN        NaN
# ...                                   ...            ...        ...
# tt7725112              (no genres listed)            NaN  nm5398596
# tt6552104              (no genres listed)            NaN  nm8794249
# tt7342916                Animation,Sci-Fi            NaN  nm8496177
# tt7575076                     Documentary            NaN  nm1098834
# tt10987544  Drama,Horror,Mystery,Thriller            NaN        NaN
#
# [165 rows x 5 columns]

# %%
df_movie_new.loc['tt0154827']
# Out:
# movie_title      Man of the Century
# movie_year                     1999
# movie_genres                 Comedy
# averageRating                   NaN
# directors                       NaN
# Name: tt0154827, dtype: object

# %%
df_ratings = pd.read_csv('./input_Neo4j/customer_ratings.csv',index_col=0)

# %%
df_ratings
# Out:
#             imdbId  rating
# userId
# c000001  tt0110912     5.0
# c000001  tt0111495     3.5
# c000001  tt0108394     5.0
# c000001  tt0114787     5.0
# c000001  tt0045152     3.5
# ...            ...     ...
# c162541  tt0382932     4.5
# c162541  tt0389790     2.5
# c162541  tt0952640     2.0
# c162541  tt0468569     4.0
# c162541  tt1013753     5.0
#
# [25000095 rows x 2 columns]

# %%
len(df_ratings['imdbId'].unique())
# Out:
# 59047

# %%
np.intersect1d(df_movie_new.index, df_ratings['imdbId'].unique()).shape
# Out:
# (59047,)

# %%
df_ratings['imdbId'].value_counts()
# Out:
# tt0109830    81491
# tt0111161    81482
# tt0110912    79672
# tt0102926    74127
# tt0133093    72674
#              ...
# tt0103292        1
# tt1486196        1
# tt0094068        1
# tt0140428        1
# tt0045887        1
# Name: imdbId, Length: 59047, dtype: int64

# %%
(df_ratings['imdbId'].value_counts()<=3).value_counts()
# Out:
# False    36193
# True     22854
# Name: imdbId, dtype: int64

# %%
# partition to 10 pieces
df_ratings.iloc[:2500000].to_csv('./input_Neo4j/customer_ratings_part1.csv')

# %%
df_ratings.iloc[:2500000]
# Out:
#             imdbId  rating
# userId
# c000001  tt0110912     5.0
# c000001  tt0111495     3.5
# c000001  tt0108394     5.0
# c000001  tt0114787     5.0
# c000001  tt0045152     3.5
# ...            ...     ...
# c016658  tt0113762     2.5
# c016658  tt0063803     3.0
# c016658  tt0099691     0.5
# c016658  tt0093624     2.5
# c016658  tt0090327     1.0
#
# [2500000 rows x 2 columns]

# %%
df_ratings.iloc[2500000:5000000].to_csv('./input_Neo4j/customer_ratings_part2.csv')
df_ratings.iloc[5000000:7500000].to_csv('./input_Neo4j/customer_ratings_part3.csv')
df_ratings.iloc[7500000:10000000].to_csv('./input_Neo4j/customer_ratings_part4.csv')
df_ratings.iloc[10000000:12500000].to_csv('./input_Neo4j/customer_ratings_part5.csv')
df_ratings.iloc[12500000:15000000].to_csv('./input_Neo4j/customer_ratings_part6.csv')
df_ratings.iloc[15000000:17500000].to_csv('./input_Neo4j/customer_ratings_part7.csv')
df_ratings.iloc[17500000:20000000].to_csv('./input_Neo4j/customer_ratings_part8.csv')
df_ratings.iloc[20000000:22500000].to_csv('./input_Neo4j/customer_ratings_part9.csv')
df_ratings.iloc[22500000:].to_csv('./input_Neo4j/customer_ratings_part10.csv')
